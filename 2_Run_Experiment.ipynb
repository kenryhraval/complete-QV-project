# %% [markdown]
# `requirements/gpu.txt`

# %%
import pandas as pd, gc, itertools
from qiskit_aer.noise import NoiseModel
from qiskit_aer import AerSimulator
from qiskit_experiments.library import QuantumVolume
from collections import defaultdict, deque
from calibration_helpers import load_payload

# %%
def noisy_simulator_from_payload(payload):
    '''Creates a noisy AerSimulator from the noise model and coupling map in the payload.'''
    
    noise_model = NoiseModel.from_dict(payload["noise_model"])
    coupling_map = payload.get("coupling_map")
    return AerSimulator(
        noise_model=noise_model,
        coupling_map=coupling_map,
        basis_gates=noise_model.basis_gates,
        method="automatic",
        device="GPU",
    )


def run_qv_for_subset(backend, ideal_backend, subset, shots=2000, trials=100, seed=42):
    '''Runs the Quantum Volume experiment for a given subset of qubits and returns the results.'''

    exp = QuantumVolume(
        physical_qubits=list(subset),
        trials=trials,
        seed=seed,
        simulation_backend=ideal_backend,
    )

    exp.set_run_options(shots=shots)

    exp.set_transpile_options(
        coupling_map=backend.coupling_map, # THIS FIXED THE ISSUE I WAS TRYING TO FIX FOR DAYS
        layout_method="trivial",
        routing_method="basic",
        optimization_level=0,
        seed_transpiler=seed,
        num_processes=0,
    )

    return exp.run(backend).block_for_results()

# %%
def build_undirected_adj(coupling_map) -> dict[int, set[int]]:
    """
    Returns adjacency dict: {q: set(neighbors)}
    """
    adj = defaultdict(set)
    for a, b in coupling_map:
        a = int(a); b = int(b)
        adj[a].add(b)
        adj[b].add(a)
    return dict(adj)


def is_connected_subset(subset, adj):
    """Check connectivity of induced subgraph on subset (undirected)."""
    subset = list(subset)
    sset = set(subset)
    start = subset[0]
    seen = {start}
    q = deque([start])
    while q:
        u = q.popleft()
        for v in adj.get(u, ()):
            if v in sset and v not in seen:
                seen.add(v)
                q.append(v)
    return len(seen) == len(subset)


def connected_triples_from_coupling(coupling_map, qubits=None):
    """
    Returns list of triples (sorted tuples) that are connected.
    If qubits is provided, restrict enumeration to those qubits.
    """
    adj = build_undirected_adj(coupling_map)

    if qubits is None:
        nodes = sorted(adj.keys())
    else:
        nodes = sorted(set(qubits))

    triples = []
    for triple in itertools.combinations(nodes, 3):
        if is_connected_subset(triple, adj):
            triples.append(triple)
    return triples

# %%
def run_qv_over_connected_triples(calibration_path, shots=2000, trials=100, seed=42, restrict_qubits=None, limit=None):
    payload = load_payload(calibration_path)
    coupling_map = payload.get("coupling_map")

    triples = connected_triples_from_coupling(coupling_map, qubits=restrict_qubits)

    if limit is not None:
        triples = triples[:limit]

    backend = noisy_simulator_from_payload(payload)
    ideal_backend = AerSimulator(method="statevector", device="GPU")

    summaries = []
    for i, triple in enumerate(triples, 1):
        print(f"[{i}/{len(triples)}] running QV on triple {triple}")

        exp_data = run_qv_for_subset(
            backend=backend,
            ideal_backend=ideal_backend,
            subset=triple,
            shots=shots,
            trials=trials,
            seed=seed,
        )

        df = exp_data.analysis_results(dataframe=True)

        hop_row = df[df["name"] == "mean_HOP"].iloc[0]

        mean_hop = hop_row["value"].nominal_value
        hop_err  = hop_row["value"].std_dev

        summaries.append((triple, mean_hop, hop_err))

        del exp_data, df
        gc.collect()

    return summaries

# %%
cal_path = "calibrations/ibm_marrakesh/20260129_101824.json"

# run on all connected triples
all_triple_expdata = run_qv_over_connected_triples(
    cal_path,
    shots=100,
    trials=100,
    seed=42,
    # limit=20,
)
# Out:
# /tmp/ipykernel_1663/418988160.py:11: DeprecationWarning: from_dict has been deprecated as of qiskit-aer 0.15.0 and will be removed no earlier than 3 months from that release date.
#   noise_model = NoiseModel.from_dict(payload["noise_model"])
# [1/244] running QV on triple (0, 1, 2)
# [2/244] running QV on triple (1, 2, 3)
# [3/244] running QV on triple (2, 3, 4)
# [4/244] running QV on triple (2, 3, 16)
# [5/244] running QV on triple (3, 4, 5)
# [6/244] running QV on triple (3, 4, 16)
# [7/244] running QV on triple (3, 16, 23)
# [8/244] running QV on triple (4, 5, 6)
# [9/244] running QV on triple (5, 6, 7)
# [10/244] running QV on triple (6, 7, 8)
# [11/244] running QV on triple (6, 7, 17)
# [12/244] running QV on triple (7, 8, 9)
# [13/244] running QV on triple (7, 8, 17)
# [14/244] running QV on triple (7, 17, 27)
# [15/244] running QV on triple (8, 9, 10)
# [16/244] running QV on triple (9, 10, 11)
# [17/244] running QV on triple (10, 11, 12)
# [18/244] running QV on triple (10, 11, 18)
# [19/244] running QV on triple (11, 12, 13)
# [20/244] running QV on triple (11, 12, 18)
# [21/244] running QV on triple (11, 18, 31)
# [22/244] running QV on triple (12, 13, 14)
# [23/244] running QV on triple (13, 14, 15)
# [24/244] running QV on triple (14, 15, 19)
# [25/244] running QV on triple (15, 19, 35)
# [26/244] running QV on triple (16, 22, 23)
# [27/244] running QV on triple (16, 23, 24)
# [28/244] running QV on triple (17, 26, 27)
# [29/244] running QV on triple (17, 27, 28)
# [30/244] running QV on triple (18, 30, 31)
# [31/244] running QV on triple (18, 31, 32)
# [32/244] running QV on triple (19, 34, 35)
# [33/244] running QV on triple (20, 21, 22)
# [34/244] running QV on triple (20, 21, 36)
# [35/244] running QV on triple (21, 22, 23)
# [36/244] running QV on triple (21, 22, 36)
# [37/244] running QV on triple (21, 36, 41)
# [38/244] running QV on triple (22, 23, 24)
# [39/244] running QV on triple (23, 24, 25)
# [40/244] running QV on triple (24, 25, 26)
# [41/244] running QV on triple (24, 25, 37)
# [42/244] running QV on triple (25, 26, 27)
# [43/244] running QV on triple (25, 26, 37)
# [44/244] running QV on triple (25, 37, 45)
# [45/244] running QV on triple (26, 27, 28)
# [46/244] running QV on triple (27, 28, 29)
# [47/244] running QV on triple (28, 29, 30)
# [48/244] running QV on triple (28, 29, 38)
# [49/244] running QV on triple (29, 30, 31)
# [50/244] running QV on triple (29, 30, 38)
# [51/244] running QV on triple (29, 38, 49)
# [52/244] running QV on triple (30, 31, 32)
# [53/244] running QV on triple (31, 32, 33)
# [54/244] running QV on triple (32, 33, 34)
# [55/244] running QV on triple (32, 33, 39)
# [56/244] running QV on triple (33, 34, 35)
# [57/244] running QV on triple (33, 34, 39)
# [195/244] running QV on triple (118, 128, 129)
# [196/244] running QV on triple (118, 129, 130)
# [197/244] running QV on triple (119, 132, 133)
# [198/244] running QV on triple (119, 133, 134)
# [199/244] running QV on triple (120, 121, 122)
# [200/244] running QV on triple (121, 122, 123)
# [201/244] running QV on triple (122, 123, 124)
# [202/244] running QV on triple (122, 123, 136)
# [203/244] running QV on triple (123, 124, 125)
# [204/244] running QV on triple (123, 124, 136)
# [205/244] running QV on triple (123, 136, 143)
# [206/244] running QV on triple (124, 125, 126)
# [207/244] running QV on triple (125, 126, 127)
# [208/244] running QV on triple (126, 127, 128)
# [209/244] running QV on triple (126, 127, 137)
# [210/244] running QV on triple (127, 128, 129)
# [211/244] running QV on triple (127, 128, 137)
# [212/244] running QV on triple (127, 137, 147)
# [213/244] running QV on triple (128, 129, 130)
# [214/244] running QV on triple (129, 130, 131)
# [215/244] running QV on triple (130, 131, 132)
# [216/244] running QV on triple (130, 131, 138)
# [217/244] running QV on triple (131, 132, 133)
# [218/244] running QV on triple (131, 132, 138)
# [219/244] running QV on triple (131, 138, 151)
# [220/244] running QV on triple (132, 133, 134)
# [221/244] running QV on triple (133, 134, 135)
# [222/244] running QV on triple (134, 135, 139)
# [223/244] running QV on triple (135, 139, 155)
# [224/244] running QV on triple (136, 142, 143)
# [225/244] running QV on triple (136, 143, 144)
# [226/244] running QV on triple (137, 146, 147)
# [227/244] running QV on triple (137, 147, 148)
# [228/244] running QV on triple (138, 150, 151)
# [229/244] running QV on triple (138, 151, 152)
# [230/244] running QV on triple (139, 154, 155)
# [231/244] running QV on triple (140, 141, 142)
# [232/244] running QV on triple (141, 142, 143)
# [233/244] running QV on triple (142, 143, 144)
# [234/244] running QV on triple (143, 144, 145)
# [235/244] running QV on triple (144, 145, 146)
# [236/244] running QV on triple (145, 146, 147)
# [237/244] running QV on triple (146, 147, 148)
# [238/244] running QV on triple (147, 148, 149)
# [239/244] running QV on triple (148, 149, 150)
# [240/244] running QV on triple (149, 150, 151)
# [241/244] running QV on triple (150, 151, 152)
# [242/244] running QV on triple (151, 152, 153)
# [243/244] running QV on triple (152, 153, 154)
# [244/244] running QV on triple (153, 154, 155)

# %%
import qiskit_aer
from qiskit_aer.noise import NoiseModel
print("Aer:", qiskit_aer.__version__)
print([m for m in dir(NoiseModel) if "map" in m.lower() or "label" in m.lower() or "remap" in m.lower()])
# Out:
# Aer: 0.15.1
# ['_instruction_names_labels']

# %%
df = pd.DataFrame(all_triple_expdata, columns=["triple", "mean_HOP", "hop_error"])
df = df.sort_values("mean_HOP", ascending=False).reset_index(drop=True)

out_csv = "results/ibm_marrakesh_qv_all_triples.csv"
df.to_csv(out_csv, index=False)
print("Saved:", out_csv)
# Out:
# Saved: results/ibm_marrakesh_qv_all_triples.csv

# %%
payload = load_payload("calibrations/ibm_marrakesh/20260129_101824.json")
coupling_map = payload.get("coupling_map")
triples = connected_triples_from_coupling(coupling_map, qubits=None)
print(f"Found {len(triples)} connected triples:")
