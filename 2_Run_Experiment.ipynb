# %% [markdown]
# `requirements/gpu.txt`

# %%
import pandas as pd, gc, rustworkx as rx
from qiskit_aer.noise import NoiseModel
from qiskit_aer import AerSimulator
from qiskit_experiments.library import QuantumVolume
from collections import defaultdict
from calibration_helpers import load_payload

# %%
def noisy_simulator_from_payload(payload):
    '''Creates a noisy AerSimulator from the noise model and coupling map in the payload.'''
    
    noise_model = NoiseModel.from_dict(payload["noise_model"])
    coupling_map = payload.get("coupling_map")
    return AerSimulator(
        noise_model=noise_model,
        coupling_map=coupling_map,
        basis_gates=noise_model.basis_gates,
        method="automatic",
        device="GPU",
    )


def run_qv_for_subset(backend, ideal_backend, subset, shots=2000, trials=100, seed=42):
    '''Runs the Quantum Volume experiment for a given subset of qubits and returns the results.'''

    exp = QuantumVolume(
        physical_qubits=list(subset),
        trials=trials,
        seed=seed,
        simulation_backend=ideal_backend,
    )

    exp.set_run_options(shots=shots)

    exp.set_transpile_options(
        coupling_map=backend.coupling_map,
        layout_method="trivial",
        routing_method="basic",
        optimization_level=0,
        seed_transpiler=seed,
        num_processes=0,
    )

    return exp.run(backend).block_for_results()

# %%
def build_undirected_adj(coupling_map) -> dict[int, set[int]]:
    """
    Returns adjacency dict: {q: set(neighbors)}
    """
    adj = defaultdict(set)
    for a, b in coupling_map:
        a = int(a); b = int(b)
        adj[a].add(b)
        adj[b].add(a)
    return dict(adj)


def connected_n_tuples_from_coupling(coupling_map, n: int):
    """
    Returns list of n-tuples (sorted tuples) that are connected (induced subgraph is connected).
    """

    nodes = sorted({int(a) for a, _ in coupling_map} | {int(b) for _, b in coupling_map})
    if n == 1:
        return [(q,) for q in nodes]
    if len(nodes) < n:
        return []

    # build mapping: qubit label -> rustworkx node index
    g = rx.PyGraph(multigraph=False)
    label_to_idx = {}
    for q in nodes:
        label_to_idx[q] = g.add_node(q)  # store the label as node payload

    # add edges
    for a, b in coupling_map:
        a = int(a); b = int(b)
        g.add_edge(label_to_idx[a], label_to_idx[b], None)

    # enumerate connected k-node subgraphs (returns lists of node indices)
    subgraphs = rx.connected_subgraphs(g, n)

    # convert node indices back to qubit labels (payloads), sort each tuple
    out = []
    for idxs in subgraphs:
        labels = sorted(g[idx] for idx in idxs)
        out.append(tuple(labels))

    # ensure uniqueness + deterministic ordering
    return sorted(set(out))

# %%
def run_qv_over_connected_n_tuples(calibration_path, n: int, shots=2000, trials=100, seed=42):
    '''Runs Quantum Volume experiments over all connected n-tuples of qubits and returns a summary of results.'''

    payload = load_payload(calibration_path)
    coupling_map = payload.get("coupling_map")

    tuples_ = connected_n_tuples_from_coupling(coupling_map, n)

    backend = noisy_simulator_from_payload(payload)
    backend.set_options(batched_shots_gpu=True)
    ideal_backend = AerSimulator(method="statevector", device="GPU")

    summaries = []
    for i, subset in enumerate(tuples_, 1):
        print(f"[{i}/{len(tuples_)}] running QV on subset {subset}")

        exp_data = run_qv_for_subset(
            backend=backend,
            ideal_backend=ideal_backend,
            subset=subset,
            shots=shots,
            trials=trials,
            seed=seed,
        )

        df = exp_data.analysis_results(dataframe=True)
        hop_row = df[df["name"] == "mean_HOP"].iloc[0]

        mean_hop = hop_row["value"].nominal_value
        hop_err  = hop_row["value"].std_dev

        summaries.append((subset, mean_hop, hop_err))

        del exp_data, df
        gc.collect()

    return summaries

# %%
cal_path = "calibrations/ibm_marrakesh/20260129_101824.json"

qubits = 6

expdata = run_qv_over_connected_n_tuples(
    cal_path,
    n=qubits,
    shots=100,
    trials=100,
    seed=42,
)

df = pd.DataFrame(expdata, columns=["subset", "mean_HOP", "hop_error"])
df = df.sort_values("mean_HOP", ascending=False).reset_index(drop=True)

out_csv = f"results/ibm_marrakesh_qv_{qubits}_tuples.csv"
df.to_csv(out_csv, index=False)
# Out:
# /tmp/ipykernel_2664/2068522216.py:4: DeprecationWarning: from_dict has been deprecated as of qiskit-aer 0.15.0 and will be removed no earlier than 3 months from that release date.
#   noise_model = NoiseModel.from_dict(payload["noise_model"])
# [1/926] running QV on subset (0, 1, 2, 3, 4, 5)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[10], line 5
#       1 cal_path = "calibrations/ibm_marrakesh/20260129_101824.json"
#       3 qubits = 6
# ----> 5 expdata = run_qv_over_connected_n_tuples(
#       6     cal_path,
#       7     n=qubits,
#       8     shots=100,
#       9     trials=100,
#      10     seed=42,
#      11 )
#      13 df = pd.DataFrame(expdata, columns=["subset", "mean_HOP", "hop_error"])
#      14 df = df.sort_values("mean_HOP", ascending=False).reset_index(drop=True)
#
# Cell In[9], line 17, in run_qv_over_connected_n_tuples(calibration_path, n, shots, trials, seed)
#      14 for i, subset in enumerate(tuples_, 1):
#      15     print(f"[{i}/{len(tuples_)}] running QV on subset {subset}")
# ---> 17     exp_data = run_qv_for_subset(
#      18         backend=backend,
#      19         ideal_backend=ideal_backend,
#      20         subset=subset,
#      21         shots=shots,
#      22         trials=trials,
#      23         seed=seed,
#      24     )
#      26     df = exp_data.analysis_results(dataframe=True)
#      27     hop_row = df[df["name"] == "mean_HOP"].iloc[0]
#
# Cell In[7], line 36, in run_qv_for_subset(backend, ideal_backend, subset, shots, trials, seed)
#      25 exp.set_run_options(shots=shots)
#      27 exp.set_transpile_options(
#      28     coupling_map=backend.coupling_map,
#      29     layout_method="trivial",
#    (...)     33     num_processes=0,
#      34 )
# ---> 36 return exp.run(backend).block_for_results()
#
# File ~/quant/QV/venv_gpu/lib/python3.12/site-packages/qiskit_experiments/framework/base_experiment.py:281, in BaseExperiment.run(self, backend, sampler, analysis, timeout, backend_run, **run_options)
#     278 run_opts = experiment.run_options.__dict__
#     280 # Run jobs
# --> 281 jobs = experiment._run_jobs(transpiled_circuits, sampler=sampler, **run_opts)
#     282 experiment_data.add_jobs(jobs, timeout=timeout)
#     284 # Optionally run analysis
#
# File ~/quant/QV/venv_gpu/lib/python3.12/site-packages/qiskit_experiments/framework/base_experiment.py:414, in BaseExperiment._run_jobs(self, circuits, sampler, **run_options)
#     411         if run_options.get("shots") is not None:
#     412             sampler.options.default_shots = run_options.get("shots")
# --> 414     jobs = [sampler.run(circs) for circs in job_circuits]
#     415 else:
#     416     jobs = [self.backend.run(circs, **run_options) for circs in job_circuits]
#
# File ~/quant/QV/venv_gpu/lib/python3.12/site-packages/qiskit_ibm_runtime/sampler.py:110, in SamplerV2.run(self, pubs, shots)
#     106 coerced_pubs = [SamplerPub.coerce(pub, shots) for pub in pubs]
#     108 validate_classical_registers(coerced_pubs)
# --> 110 return self._run(coerced_pubs)
#
# File ~/quant/QV/venv_gpu/lib/python3.12/site-packages/qiskit_ibm_runtime/base_primitive.py:190, in BasePrimitiveV2._run(self, pubs)
#     181 if isinstance(self._service, QiskitRuntimeService):
#     182     return self._service._run(
#     183         program_id=self._program_id(),
#     184         options=runtime_options,
#    (...)    187         result_decoder=DEFAULT_DECODERS.get(self._program_id()),
#     188     )
# --> 190 return self._service._run(
#     191     program_id=self._program_id(),  # type: ignore[arg-type]
#     192     options=runtime_options,
#     193     inputs=primitive_inputs,
#     194 )
#
# File ~/quant/QV/venv_gpu/lib/python3.12/site-packages/qiskit_ibm_runtime/fake_provider/local_service.py:169, in QiskitRuntimeLocalService._run(self, program_id, inputs, options)
#     153 """Execute the runtime program.
#     154
#     155 Args:
#    (...)    166     NotImplementedError: If using V2 primitives.
#     167 """
#     168 if isinstance(options, Dict):
# --> 169     qrt_options = copy.deepcopy(options)
#     170 else:
#     171     qrt_options = asdict(options)
#
# File /usr/lib/python3.12/copy.py:136, in deepcopy(x, memo, _nil)
#     134 copier = _deepcopy_dispatch.get(cls)
#     135 if copier is not None:
# --> 136     y = copier(x, memo)
#     137 else:
#     138     if issubclass(cls, type):
#
# File /usr/lib/python3.12/copy.py:221, in _deepcopy_dict(x, memo, deepcopy)
#     219 memo[id(x)] = y
#     220 for key, value in x.items():
# --> 221     y[deepcopy(key, memo)] = deepcopy(value, memo)
#     222 return y
#
# File /usr/lib/python3.12/copy.py:162, in deepcopy(x, memo, _nil)
#     160                 y = x
#     161             else:
# --> 162                 y = _reconstruct(x, memo, *rv)
#     164 # If is its own copy, don't memoize.
#     165 if y is not x:
#
# File /usr/lib/python3.12/copy.py:259, in _reconstruct(x, memo, func, args, state, listiter, dictiter, deepcopy)
#     257 if state is not None:
#     258     if deep:
# --> 259         state = deepcopy(state, memo)
#     260     if hasattr(y, '__setstate__'):
#     261         y.__setstate__(state)
#
# File /usr/lib/python3.12/copy.py:136, in deepcopy(x, memo, _nil)
#     134 copier = _deepcopy_dispatch.get(cls)
#     135 if copier is not None:
# --> 136     y = copier(x, memo)
#     137 else:
#     138     if issubclass(cls, type):
#
# File /usr/lib/python3.12/copy.py:221, in _deepcopy_dict(x, memo, deepcopy)
#     219 memo[id(x)] = y
#     220 for key, value in x.items():
# --> 221     y[deepcopy(key, memo)] = deepcopy(value, memo)
#     222 return y
#
# File /usr/lib/python3.12/copy.py:162, in deepcopy(x, memo, _nil)
#     160                 y = x
#     161             else:
# --> 162                 y = _reconstruct(x, memo, *rv)
#     164 # If is its own copy, don't memoize.
#     165 if y is not x:
#
# File /usr/lib/python3.12/copy.py:259, in _reconstruct(x, memo, func, args, state, listiter, dictiter, deepcopy)
#     257 if state is not None:
#     258     if deep:
# --> 259         state = deepcopy(state, memo)
#     260     if hasattr(y, '__setstate__'):
#     261         y.__setstate__(state)
#
# File /usr/lib/python3.12/copy.py:136, in deepcopy(x, memo, _nil)
#     134 copier = _deepcopy_dispatch.get(cls)
#     135 if copier is not None:
# --> 136     y = copier(x, memo)
#     137 else:
#     138     if issubclass(cls, type):
#
# File /usr/lib/python3.12/copy.py:201, in _deepcopy_tuple(x, memo, deepcopy)
#     200 def _deepcopy_tuple(x, memo, deepcopy=deepcopy):
# --> 201     y = [deepcopy(a, memo) for a in x]
#     202     # We're not going to put the tuple in the memo, but it's still important we
#     203     # check for it, in case the tuple contains recursive mutable structures.
#     204     try:
#
# File /usr/lib/python3.12/copy.py:136, in deepcopy(x, memo, _nil)
#     134 copier = _deepcopy_dispatch.get(cls)
#     135 if copier is not None:
# --> 136     y = copier(x, memo)
#     137 else:
#     138     if issubclass(cls, type):
#
# File /usr/lib/python3.12/copy.py:221, in _deepcopy_dict(x, memo, deepcopy)
#     219 memo[id(x)] = y
#     220 for key, value in x.items():
# --> 221     y[deepcopy(key, memo)] = deepcopy(value, memo)
#     222 return y
#
# File /usr/lib/python3.12/copy.py:162, in deepcopy(x, memo, _nil)
#     160                 y = x
#     161             else:
# --> 162                 y = _reconstruct(x, memo, *rv)
#     164 # If is its own copy, don't memoize.
#     165 if y is not x:
#
# File /usr/lib/python3.12/copy.py:259, in _reconstruct(x, memo, func, args, state, listiter, dictiter, deepcopy)
#     257 if state is not None:
#     258     if deep:
# --> 259         state = deepcopy(state, memo)
#     260     if hasattr(y, '__setstate__'):
#     261         y.__setstate__(state)
#
# File /usr/lib/python3.12/copy.py:136, in deepcopy(x, memo, _nil)
#     134 copier = _deepcopy_dispatch.get(cls)
#     135 if copier is not None:
# --> 136     y = copier(x, memo)
#     137 else:
#     138     if issubclass(cls, type):
#
# File /usr/lib/python3.12/copy.py:221, in _deepcopy_dict(x, memo, deepcopy)
#     219 memo[id(x)] = y
#     220 for key, value in x.items():
# --> 221     y[deepcopy(key, memo)] = deepcopy(value, memo)
#     222 return y
#
#     [... skipping similar frames: _deepcopy_dict at line 221 (2 times), deepcopy at line 136 (2 times)]
#
# File /usr/lib/python3.12/copy.py:162, in deepcopy(x, memo, _nil)
#     160                 y = x
#     161             else:
# --> 162                 y = _reconstruct(x, memo, *rv)
#     164 # If is its own copy, don't memoize.
#     165 if y is not x:
#
# File /usr/lib/python3.12/copy.py:259, in _reconstruct(x, memo, func, args, state, listiter, dictiter, deepcopy)
#     257 if state is not None:
#     258     if deep:
# --> 259         state = deepcopy(state, memo)
#     260     if hasattr(y, '__setstate__'):
#     261         y.__setstate__(state)
#
#     [... skipping similar frames: deepcopy at line 136 (1 times)]
#
# File /usr/lib/python3.12/copy.py:221, in _deepcopy_dict(x, memo, deepcopy)
#     219 memo[id(x)] = y
#     220 for key, value in x.items():
# --> 221     y[deepcopy(key, memo)] = deepcopy(value, memo)
#     222 return y
#
# File /usr/lib/python3.12/copy.py:136, in deepcopy(x, memo, _nil)
#     134 copier = _deepcopy_dispatch.get(cls)
#     135 if copier is not None:
# --> 136     y = copier(x, memo)
#     137 else:
#     138     if issubclass(cls, type):
#
# File /usr/lib/python3.12/copy.py:196, in _deepcopy_list(x, memo, deepcopy)
#     194 append = y.append
#     195 for a in x:
# --> 196     append(deepcopy(a, memo))
#     197 return y
#
# File /usr/lib/python3.12/copy.py:143, in deepcopy(x, memo, _nil)
#     141 copier = getattr(x, "__deepcopy__", None)
#     142 if copier is not None:
# --> 143     y = copier(memo)
#     144 else:
#     145     reductor = dispatch_table.get(cls)
#
# File ~/quant/QV/venv_gpu/lib/python3.12/site-packages/qiskit/circuit/quantumcircuit.py:1432, in QuantumCircuit.__deepcopy__(self, memo)
#    1430 result = cls.__new__(cls)
#    1431 for k in self.__dict__.keys() - {"_data", "_builder_api"}:
# -> 1432     setattr(result, k, _copy.deepcopy(self.__dict__[k], memo))
#    1434 result._builder_api = _OuterCircuitScopeInterface(result)
#    1436 # Avoids pulling self._data into a Python list
#    1437 # like we would when pickling.
#
# File /usr/lib/python3.12/copy.py:136, in deepcopy(x, memo, _nil)
#     134 copier = _deepcopy_dispatch.get(cls)
#     135 if copier is not None:
# --> 136     y = copier(x, memo)
#     137 else:
#     138     if issubclass(cls, type):
#
# File /usr/lib/python3.12/copy.py:221, in _deepcopy_dict(x, memo, deepcopy)
#     219 memo[id(x)] = y
#     220 for key, value in x.items():
# --> 221     y[deepcopy(key, memo)] = deepcopy(value, memo)
#     222 return y
#
# File /usr/lib/python3.12/copy.py:162, in deepcopy(x, memo, _nil)
#     160                 y = x
#     161             else:
# --> 162                 y = _reconstruct(x, memo, *rv)
#     164 # If is its own copy, don't memoize.
#     165 if y is not x:
#
# File /usr/lib/python3.12/copy.py:253, in _reconstruct(x, memo, func, args, state, listiter, dictiter, deepcopy)
#     251 if deep and args:
#     252     args = (deepcopy(arg, memo) for arg in args)
# --> 253 y = func(*args)
#     254 if deep:
#     255     memo[id(x)] = y
#
# File /usr/lib/python3.12/copy.py:252, in <genexpr>(.0)
#     250 deep = memo is not None
#     251 if deep and args:
# --> 252     args = (deepcopy(arg, memo) for arg in args)
#     253 y = func(*args)
#     254 if deep:
#
# File /usr/lib/python3.12/copy.py:136, in deepcopy(x, memo, _nil)
#     134 copier = _deepcopy_dispatch.get(cls)
#     135 if copier is not None:
# --> 136     y = copier(x, memo)
#     137 else:
#     138     if issubclass(cls, type):
#
# File /usr/lib/python3.12/copy.py:196, in _deepcopy_list(x, memo, deepcopy)
#     194 append = y.append
#     195 for a in x:
# --> 196     append(deepcopy(a, memo))
#     197 return y
#
# File /usr/lib/python3.12/copy.py:136, in deepcopy(x, memo, _nil)
#     134 copier = _deepcopy_dispatch.get(cls)
#     135 if copier is not None:
# --> 136     y = copier(x, memo)
#     137 else:
#     138     if issubclass(cls, type):
#
# File /usr/lib/python3.12/copy.py:201, in _deepcopy_tuple(x, memo, deepcopy)
#     200 def _deepcopy_tuple(x, memo, deepcopy=deepcopy):
# --> 201     y = [deepcopy(a, memo) for a in x]
#     202     # We're not going to put the tuple in the memo, but it's still important we
#     203     # check for it, in case the tuple contains recursive mutable structures.
#     204     try:
#
# File /usr/lib/python3.12/copy.py:162, in deepcopy(x, memo, _nil)
#     160                 y = x
#     161             else:
# --> 162                 y = _reconstruct(x, memo, *rv)
#     164 # If is its own copy, don't memoize.
#     165 if y is not x:
#
# File /usr/lib/python3.12/copy.py:259, in _reconstruct(x, memo, func, args, state, listiter, dictiter, deepcopy)
#     257 if state is not None:
#     258     if deep:
# --> 259         state = deepcopy(state, memo)
#     260     if hasattr(y, '__setstate__'):
#     261         y.__setstate__(state)
#
# File /usr/lib/python3.12/copy.py:136, in deepcopy(x, memo, _nil)
#     134 copier = _deepcopy_dispatch.get(cls)
#     135 if copier is not None:
# --> 136     y = copier(x, memo)
#     137 else:
#     138     if issubclass(cls, type):
#
# File /usr/lib/python3.12/copy.py:201, in _deepcopy_tuple(x, memo, deepcopy)
#     200 def _deepcopy_tuple(x, memo, deepcopy=deepcopy):
# --> 201     y = [deepcopy(a, memo) for a in x]
#     202     # We're not going to put the tuple in the memo, but it's still important we
#     203     # check for it, in case the tuple contains recursive mutable structures.
#     204     try:
#
# File /usr/lib/python3.12/copy.py:136, in deepcopy(x, memo, _nil)
#     134 copier = _deepcopy_dispatch.get(cls)
#     135 if copier is not None:
# --> 136     y = copier(x, memo)
#     137 else:
#     138     if issubclass(cls, type):
#
# File /usr/lib/python3.12/copy.py:196, in _deepcopy_list(x, memo, deepcopy)
#     194 append = y.append
#     195 for a in x:
# --> 196     append(deepcopy(a, memo))
#     197 return y
#
# File /usr/lib/python3.12/copy.py:143, in deepcopy(x, memo, _nil)
#     141 copier = getattr(x, "__deepcopy__", None)
#     142 if copier is not None:
# --> 143     y = copier(memo)
#     144 else:
#     145     reductor = dispatch_table.get(cls)
#
# File ~/quant/QV/venv_gpu/lib/python3.12/site-packages/qiskit/circuit/bit.py:90, in Bit.__deepcopy__(self, memo)
#      87 # Old-style bits need special handling for now, since some code seems
#      88 # to rely on their registers getting deep-copied.
#      89 bit = type(self).__new__(type(self))
# ---> 90 bit._register = copy.deepcopy(self._register, memo)
#      91 bit._index = self._index
#      92 bit._hash = self._hash
#
# File /usr/lib/python3.12/copy.py:118, in deepcopy(x, memo, _nil)
#     114 d[bytearray] = bytearray.copy
#     116 del d, t
# --> 118 def deepcopy(x, memo=None, _nil=[]):
#     119     """Deep copy operation on arbitrary Python objects.
#     120
#     121     See the module's __doc__ string for more info.
#     122     """
#     124     if memo is None:
#
# KeyboardInterrupt:
